# %% [markdown]
# ## Dash
#
# What is Dash? This [introduction](https://dash.plot.ly/introduction) gives you a basic understanding of Dash, and how it leverages Flask, Plotly and React. Dash allows us to use Plotly without writing HTML or Javascript code.
#
# The first step is [installation](https://dash.plot.ly/installation) of Dash and its dependencies:
#
# Here's how to make your [first Dash App](https://dash.plot.ly/getting-started). Copy paste the code in the link into a text editor, and save the file as 'App.py'. Then navigate to the relevant folder, and call python App.py in the terminal. Next, open a new window in your broswer and navigate to http://127.0.0.1:8050/. You should see your new data visualization. Use control+c to exit the app
#
# Now work with the accompanying code chunk below for further exploration. Use the stop button on your menu bar to exit the app

# %%
# !pip install dash
# Out:
# Collecting dash
#   Downloading dash-1.14.0.tar.gz (70 kB)
# Requirement already satisfied: Flask>=1.0.2 in c:\users\mlxp\anaconda3\lib\site-packages (from dash) (1.1.2)
# Collecting flask-compress
#   Downloading Flask-Compress-1.5.0.tar.gz (6.5 kB)
# Collecting plotly
#   Using cached plotly-4.9.0-py2.py3-none-any.whl (12.9 MB)
# Collecting dash_renderer==1.6.0
#   Downloading dash_renderer-1.6.0.tar.gz (1.2 MB)
# Collecting dash-core-components==1.10.2
#   Downloading dash_core_components-1.10.2.tar.gz (3.4 MB)
# Collecting dash-html-components==1.0.3
#   Downloading dash_html_components-1.0.3.tar.gz (187 kB)
# Collecting dash-table==4.9.0
#   Downloading dash_table-4.9.0.tar.gz (1.8 MB)
# Requirement already satisfied: future in c:\users\mlxp\anaconda3\lib\site-packages (from dash) (0.18.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\mlxp\anaconda3\lib\site-packages (from Flask>=1.0.2->dash) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\mlxp\anaconda3\lib\site-packages (from Flask>=1.0.2->dash) (1.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\mlxp\anaconda3\lib\site-packages (from Flask>=1.0.2->dash) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\mlxp\anaconda3\lib\site-packages (from Flask>=1.0.2->dash) (2.11.2)
# Collecting brotli
#   Downloading Brotli-1.0.7-cp38-cp38-win_amd64.whl (358 kB)
# Requirement already satisfied: six in c:\users\mlxp\anaconda3\lib\site-packages (from plotly->dash) (1.15.0)
# Collecting retrying>=1.3.3
#   Using cached retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\mlxp\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.2->dash) (1.1.1)
# Building wheels for collected packages: dash, flask-compress, dash-renderer, dash-core-components, dash-html-components, dash-table, retrying
#   Building wheel for dash (setup.py): started
#   Building wheel for dash (setup.py): finished with status 'done'
#   Created wheel for dash: filename=dash-1.14.0-py3-none-any.whl size=80132 sha256=72f087710e2c09269403dbfa1a4863f49de3fb9e184cbbb1a458123c0b84516c
#   Stored in directory: c:\users\mlxp\appdata\local\pip\cache\wheels\ff\a5\77\633ec617c6fa139fa32b868c02e93bc85a32437f5083f48170
#   Building wheel for flask-compress (setup.py): started
#   Building wheel for flask-compress (setup.py): finished with status 'done'
#   Created wheel for flask-compress: filename=Flask_Compress-1.5.0-py3-none-any.whl size=5277 sha256=45308032854c8300c40434f64a9b32fcec54a9ef1e57821e9b6e0ce5139a1ab8
#   Stored in directory: c:\users\mlxp\appdata\local\pip\cache\wheels\39\3f\1a\07c215cf8b8f924cde78277257a31e254ef267ade7a99c909e
#   Building wheel for dash-renderer (setup.py): started
#   Building wheel for dash-renderer (setup.py): finished with status 'done'
#   Created wheel for dash-renderer: filename=dash_renderer-1.6.0-py3-none-any.whl size=1182223 sha256=b651b8dd8fa53bfe94c4f744a280ee94887d76e770d5f5517be18e8cc3349716
#   Stored in directory: c:\users\mlxp\appdata\local\pip\cache\wheels\31\66\a5\0c447daeb2fc7e796538b5832fce2e2910312f606b13219de8
#   Building wheel for dash-core-components (setup.py): started
#   Building wheel for dash-core-components (setup.py): finished with status 'done'
#   Created wheel for dash-core-components: filename=dash_core_components-1.10.2-py3-none-any.whl size=3457327 sha256=0c4102dcb53f1d40f567866362056e05a66619b0455b09f02ac3804708d8b61e
#   Stored in directory: c:\users\mlxp\appdata\local\pip\cache\wheels\f1\92\c9\c6fd5c7e05f08af6c5b162dec3e661af6f7ef25a6acc5f1304
#   Building wheel for dash-html-components (setup.py): started
#   Building wheel for dash-html-components (setup.py): finished with status 'done'
#   Created wheel for dash-html-components: filename=dash_html_components-1.0.3-py3-none-any.whl size=427310 sha256=a717e6fbff585ac765bcc2dbed485e1949190317ff0e1ec3c5a28e20bece3260
#   Stored in directory: c:\users\mlxp\appdata\local\pip\cache\wheels\1b\95\e3\1e5e36f1c179288ab4ee6ef739987161416de82ced3b898cf8
#   Building wheel for dash-table (setup.py): started
#   Building wheel for dash-table (setup.py): finished with status 'done'
#   Created wheel for dash-table: filename=dash_table-4.9.0-py3-none-any.whl size=1780771 sha256=6be242dd5b834c81f78804af2e861b595db7f4e1bae5d73b0b4637fc0c3718cb
#   Stored in directory: c:\users\mlxp\appdata\local\pip\cache\wheels\ff\7e\f9\cea86201fdc6aea9e9b9b314fbcc9a3f62af08845474000f83
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11435 sha256=9cf309e9bb95ec16cfa662070833b1275590e631d1229222861e69ed82cd9857
#   Stored in directory: c:\users\mlxp\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built dash flask-compress dash-renderer dash-core-components dash-html-components dash-table retrying
# Installing collected packages: brotli, flask-compress, retrying, plotly, dash-renderer, dash-core-components, dash-html-components, dash-table, dash
# Successfully installed brotli-1.0.7 dash-1.14.0 dash-core-components-1.10.2 dash-html-components-1.0.3 dash-renderer-1.6.0 dash-table-4.9.0 flask-compress-1.5.0 plotly-4.9.0 retrying-1.3.3

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\mlxp\anaconda3\lib\site-packages (4.9.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\mlxp\anaconda3\lib\site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in c:\users\mlxp\anaconda3\lib\site-packages (from plotly) (1.15.0)

# %%
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go

app = dash.Dash()
app.css.config.serve_locally = True
app.scripts.config.serve_locally = True

df = pd.read_csv(
    'https://gist.githubusercontent.com/chriddyp/' +
    '5d1ea79569ed194d432e56108a04d188/raw/' +
    'a9f9e8076b837d541398e999dcbac2b2826a81f8/'+
    'gdp-life-exp-2007.csv')


app.layout = html.Div([
    dcc.Graph(
        id='life-exp-vs-gdp',
        figure={
            'data': [
                go.Scatter(
                    x=df[df['continent'] == i]['gdp per capita'],
                    y=df[df['continent'] == i]['life expectancy'],
                    text=df[df['continent'] == i]['country'],
                    mode='markers',
                    opacity=0.7,
                    marker={
                        'size': 15,
                        'line': {'width': 0.5, 'color': 'white'}
                    },
                    name=i
                ) for i in df.continent.unique()
            ],
            'layout': go.Layout(
                xaxis={'type': 'log', 'title': 'GDP Per Capita'},
                yaxis={'title': 'Life Expectancy'},
                margin={'l': 40, 'b': 40, 't': 10, 'r': 10},
                legend={'x': 0, 'y': 1},
                hovermode='closest'
            )
        }
    )
])

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  Warning: This is a development server. Do not use app.run_server
#  in production, use a production WSGI server like gunicorn instead.
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [28/Jul/2020 13:53:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2020 13:53:54] "GET /_dash-component-suites/dash_renderer/prop-types@15.v1_6_0m1595962341.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2020 13:53:54] "GET /_dash-component-suites/dash_renderer/polyfill@7.v1_6_0m1595962341.8.7.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2020 13:53:54] "GET /_dash-component-suites/dash_renderer/react@16.v1_6_0m1595962341.13.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2020 13:53:54] "GET /_dash-component-suites/dash_html_components/dash_html_components.v1_0_3m1595962343.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2020 13:53:54] "GET /_dash-component-suites/dash_renderer/react-dom@16.v1_6_0m1595962341.13.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2020 13:53:54] "GET /_dash-component-suites/dash_core_components/dash_core_components.v1_10_2m1595962342.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2020 13:53:54] "GET /_dash-component-suites/dash_core_components/dash_core_components-shared.v1_10_2m1595962342.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2020 13:53:54] "GET /_dash-component-suites/dash_renderer/dash_renderer.v1_6_0m1595962341.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2020 13:53:54] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2020 13:53:54] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2020 13:53:54] "GET /_favicon.ico?v=1.14.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2020 13:53:54] "GET /_dash-component-suites/dash_core_components/async-graph.v1_10_2m1595872686.js HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2020 13:53:54] "GET /_dash-component-suites/dash_core_components/async-plotlyjs.v1_10_2m1595872686.js HTTP/1.1" 200 -

# %% [markdown]
# Now work with our familiar example of unemployment data with the accompanying code chunk below for further exploration. Notice that we are embedding the previously used Plotly objects within the Dash app. Use the stop button on your menu bar to exit the app

# %%
unemployment_df = pd.read_excel('https://www.ers.usda.gov/webdocs/DataFiles/48747/Unemployment.xls?v=0', header = 7)
unemployment_df = unemployment_df.dropna()

df_2 = unemployment_df[['Area_name','Unemployment_rate_2007','Unemployment_rate_2008','Unemployment_rate_2009',
       'Unemployment_rate_2010','Unemployment_rate_2011','Unemployment_rate_2012','Unemployment_rate_2013',
       'Unemployment_rate_2014','Unemployment_rate_2015','Unemployment_rate_2016','Unemployment_rate_2017']]


app = dash.Dash()
app.css.config.serve_locally = True
app.scripts.config.serve_locally = True

app.layout = html.Div([
    dcc.Graph(
        id='Unemployment Rate for Counties by Year',
        figure={
            'data': [
                go.Scatter(
                    x=[x for x in range(2007, 2018)],
                    y=df_2[df_2['Area_name'] == 'Autauga County, AL'].iloc[:,1:].values[0].tolist(),
                    text=df_2[df_2['Area_name'] == 'Autauga County, AL'].iloc[:,1:].values[0].tolist(),
                    mode='lines+markers',
                    opacity=0.7,
                    name = 'Autauga, AL',
                    marker={
                        'size': 8,
                        'line': {'width': 0.5, 'color': 'white'}
                    },
                    
                ),
             go.Scatter(
                    x=[x for x in range(2007,2018)],
                    y= df_2[df_2['Area_name'] == 'Hartford County, CT'].iloc[:,1:].values[0].tolist(),
                    text=df_2[df_2['Area_name'] == 'Hartford County, CT'].iloc[:,1:].values[0].tolist(),
                    mode='lines+markers',
                    opacity=0.7,
                    name = 'Hartford, CT',
                    marker={
                        'size': 8,
                        'line': {'width': 0.5, 'color': 'white'}
                    }
                ),
                go.Scatter(
                    x=[x for x in range(2007, 2018)],
                    y=df_2[df_2['Area_name'] == 'Carlisle County, KY'].iloc[:,1:].values[0].tolist(),
                    text=df_2[df_2['Area_name'] == 'Carlisle County, KY'].iloc[:,1:].values[0].tolist(),
                    mode='lines+markers',
                    opacity=0.7,
                    name = 'Crlisle, KY',
                    marker={
                        'size': 8,
                        'line': {'width': 0.5, 'color': 'white'}
                    },
                    
                ),
             go.Scatter(
                    x=[x for x in range(2007,2018)],
                    y= df_2[df_2['Area_name'] == 'Dallas County, TX'].iloc[:,1:].values[0].tolist(),
                    text=df_2[df_2['Area_name'] == 'Dallas County, TX'].iloc[:,1:].values[0].tolist(),
                    mode='lines+markers',
                    opacity=0.7,
                    name = 'Dallas, TX',
                    marker={
                        'size': 8,
                        'line': {'width': 0.5, 'color': 'white'}
                    }
                ),
            ],
            'layout': go.Layout(
                xaxis={'type': 'log', 'title': 'Year'},
                yaxis={'title': '% Unemployed'},
                margin={'l': 40, 'b': 40, 't': 40, 'r': 10},
                legend={'x': 0, 'y': 1},
                title='Unemployment Rate for Counties by Year',
                hovermode='closest'
            )
        }
    )
])

if __name__ == '__main__':
    app.run_server()
